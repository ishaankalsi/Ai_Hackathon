# %%
import pandas as pd

# %%
df = pd.read_csv("/home/ishaan/Codes/Presentations/ai_hack_data/survey2016.csv/survey2016.csv")

# %%
import numpy as np

# %%
list(df.keys())
# Out:
# ['self-employed',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health concerns and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
# ...

# %% [markdown]
# # clean the data

# %%
# drop all columns without Yes/No tyoe structure

# %%
for x in list(df.columns):
    if "Yes" in df[x].values:
        continue
    else :
        df = df.drop(columns=[x])

# %%
df.shape
# Out:
# (1433, 27)

# %%
# replace all none values with 3

# %%
df = df.fillna(float(0.1))

# %%
df
# Out:
#      self-employed Is your employer primarily a tech company/organization?  \
# 0               No                                                Yes
# 1               No                                                Yes
# 2               No                                                Yes
# 3              Yes                                                0.1
# 4               No                                                 No
# 5               No                                                Yes
# 6               No                                                Yes
# 7               No                                                Yes
# 8               No                                                 No
# 9              Yes                                                0.1
# 10              No                                                Yes
# 11              No                                                 No
# ...

# %%
print(type(df))
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1433, 27)

# %%
df.values[0][0]
# Out:
# 'No'

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
for i in range(df.shape[0]) :
    for j in range(df.shape[1]) :
        
#         if df.values[i][j] == "Yes" or df.values[i][j] == "yes":
        if str(df.values[i][j]) == "Yes":
#             print(df.values[i][j])
            df.values[i][j] = float(20)
#             print(df.values[i][j])
#         if df.values[i][j] == "No" or df.values[i][j] == "no":
        if str(df.values[i][j]) == "No":
            df.values[i][j] = float(10)

# %%
print(type(df.values[0][0]))
# Out:
# <class 'int'>

# %%
a = 2
if(type(a) == str):
    print("yes")
else:
    print("no")
print(type(a))
# Out:
# no
# <class 'int'>

# %%
# replace values as 2 if they are not 0/1/3

for i in range(df.shape[0]) :
    for j in range(df.shape[1]) :
        if(type(df.values[i][j]) != float ):
            df.values[i][j] = float(30)
        
            
#         if df.values[i][j] == "Yes" or df.values[i][j] == "yes":
#         if str(df.values[i][j]) != "0" or str(df.values[i][j]) != "1" or str(df.values[i][j]) != "3"  :
#             df.values[i][j] = 2

# %%
df.shape
# Out:
# (1433, 27)

# %%
print(df.columns.get_loc("Do you currently have a mental health disorder?"))
# Out:
# 24

# %%
x = df[df.columns[:24]]
y = df[df.columns[24]]

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_)
# lets plot
feat_imps = pd.Series(model.feature_importances_,index=x.columns)
feat_imps.nlargest(10).plot(kind = "barh")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-363-41a57751bdbf> in <module>()
#       1 model = ExtraTreesClassifier()
# ----> 2 model.fit(x,y)
#       3 print(model.feature_importances_)
#       4 # lets plot
#       5 feat_imps = pd.Series(model.feature_importances_,index=x.columns)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
#     275         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_y_class_weight(self, y)
#     469
#     470     def _validate_y_class_weight(self, y):
# --> 471         check_classification_targets(y)
#     472
# ...

# %% [markdown]
# ## Analyse Data

# %%
print(len(list(df.keys())))
# Out:
# 27

# %%
print(df.columns.get_loc("Do you currently have a mental health disorder?"))
# Out:
# 24

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

# %%
#x = df.iloc[:, x for x in df.columns.values if df.columns != "Do you currently have a mental health disorder?"]
x = df.iloc[:,df.columns !="Do you currently have a mental health disorder?"]
y = df.iloc[:,df.columns =="Do you currently have a mental health disorder?"]

# %%
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Feature importance

# %%
np.unique(y)
# Out:
# array([0, 1, 2], dtype=object)

# %%
x = df.iloc[:,df.columns.astype(int) !="Do you currently have a mental health disorder?"]
y = df.iloc[:,df.columns.astype(int) =="Do you currently have a mental health disorder?"]
x = x.astype(str)
y = y.astype(str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in astype(self, dtype, copy)
#    1277         try:
# -> 1278             return Index(self.values.astype(dtype, copy=copy), name=self.name,
#    1279                          dtype=dtype)
#
# ValueError: invalid literal for int() with base 10: 'self-employed'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-325-4b6f56609921> in <module>()
# ----> 1 x = df.iloc[:,df.columns.astype(int) !="Do you currently have a mental health disorder?"]
#       2 y = df.iloc[:,df.columns.astype(int) =="Do you currently have a mental health disorder?"]
#       3 x = x.astype(str)
#       4 y = y.astype(str)
#
# ...

# %%
#create data relation
# x = df.iloc[:,df.columns != "Do you currently have a mental health disorder?"]
# y = df.iloc[:,df.columns == "Do you currently have a mental health disorder?"]

x = df.iloc[:,df.columns !="Do you currently have a mental health disorder?"]
y = df.iloc[:,df.columns =="Do you currently have a mental health disorder?"]
print(type(x),type(y),x.shape,y.shape)
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_)
# lets plot
feat_imps = pd.Series(model.feature_importances_,index=x.columns)
feat_imps.nlargest(10).plot(kind = "barh")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'> (1433, 26) (1433, 1)
# /home/ishaan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-60dd23ad85cc> in <module>()
#       7 print(type(x),type(y),x.shape,y.shape)
#       8 model = ExtraTreesClassifier()
# ----> 9 model.fit(x,y)
#      10 print(model.feature_importances_)
#      11 # lets plot
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
# ...

# %%
##########################################################################

# %%
# Build a forest and compute the feature importances
x = df.iloc[:,df.columns !="Do you currently have a mental health disorder?"]
y = df.iloc[:,df.columns =="Do you currently have a mental health disorder?"]
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(x, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

labels = []
for f in range(x.shape[1]):
    labels.append(feature_cols[f])      
    
# Plot the feature importances of the forest
plt.figure(figsize=(12,8))
plt.title("Feature importances")
plt.bar(range(x.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(x.shape[1]), labels, rotation='vertical')
plt.xlim([-1, x.shape[1]])
plt.show()
# Out:
# /home/ishaan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-317-ba9902a42c97> in <module>()
#       5                               random_state=0)
#       6
# ----> 7 forest.fit(x, y)
#       8 importances = forest.feature_importances_
#       9 std = np.std([tree.feature_importances_ for tree in forest.estimators_],
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
# ...

# %%
##########################################################################################

# %%
import sklearn.linear_model as lm
from sklearn import metrics, preprocessing

# %%
class greedyFeatureSelection(object):

    def __init__(self, data, labels, scale=1, verbose=0):
        if scale == 1:
            self._data = preprocessing.scale(np.array(data))
        else:
            self._data = np.array(data)
        self._labels = labels
        self._verbose = verbose

    def evaluateScore(self, X, y):
        model = lm.LogisticRegression()
        model.fit(X, y)
        predictions = model.predict_proba(X)[:, 1]
        auc = metrics.roc_auc_score(y, predictions)
        return auc

    def selectionLoop(self, X, y):
        score_history = []
        good_features = set([])
        num_features = X.shape[1]
        while len(score_history) < 2 or score_history[-1][0] > score_history[-2][0]:
            scores = []
            for feature in range(num_features):
                if feature not in good_features:
                    selected_features = list(good_features) + [feature]

                    Xts = np.column_stack(X[:, j] for j in selected_features)

                    score = self.evaluateScore(Xts, y)
                    scores.append((score, feature))

                    if self._verbose:
                        print ("Current AUC : ", np.mean(score))

            good_features.add(sorted(scores)[-1][1])
            score_history.append(sorted(scores)[-1])
            if self._verbose:
                print ("Current Features : ", sorted(list(good_features)))

        # Remove last added feature
        good_features.remove(score_history[-1][1])
        good_features = sorted(list(good_features))
        if self._verbose:
            print ("Selected Features : ", good_features)

        return good_features

    def transform(self, X):
        X = self._data
        y = self._labels
        good_features = self.selectionLoop(X, y)
        return X[:, good_features]

# %%
obj = greedyFeatureSelection(x,y)
# Out:
# /home/ishaan/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
features = obj.selectionLoop(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-300-4ca69108ef81> in <module>()
# ----> 1 features = obj.selectionLoop(x,y)
#
# <ipython-input-298-9a3ea84a545c> in selectionLoop(self, X, y)
#      28                     selected_features = list(good_features) + [feature]
#      29
# ---> 30                     Xts = np.column_stack(X[:, j] for j in selected_features)
#      31
#      32                     score = self.evaluateScore(Xts, y)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/shape_base.py in column_stack(tup)
#     346     """
#     347     arrays = []
# --> 348     for v in tup:
#     349         arr = array(v, copy=False, subok=True)
#     350         if arr.ndim < 2:
#
# <ipython-input-298-9a3ea84a545c> in <genexpr>(.0)
#      28                     selected_features = list(good_features) + [feature]
#      29
# ...

# %% [markdown]
# ## Heatmap

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# x = data.iloc[:,0:20]  #independent columns
# y = data.iloc[:,-1]    #target column i.e price range
#get correlations of each features in dataset
x = df.iloc[:,df.columns != "Do you currently have a mental health disorder?"]
y = df.iloc[:,df.columns.get_loc("Do you currently have a mental health disorder?")]
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-216-1a1d74ceb9fd> in <module>()
#      11 plt.figure(figsize=(20,20))
#      12 #plot heat map
# ---> 13 g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...
